# %%
pwd
# Out:
# '/fast/AG_Bunina/Yusuf/jobs'

# %%
# Use episcanpy python 3.8 kernel.

# %%
cd '/fast/AG_Bunina/Yusuf/Project_Endothelial_and_Stroke/Datasets/Chromatin_and_Gene_Exp/2023_Zhu_et_al/Zhu_et_al_2023/Python_Project/ScenicPlus/Zhu_et_al'
# Out:
# /fast/AG_Bunina/Yusuf/Project_Endothelial_and_Stroke/Datasets/Chromatin_and_Gene_Exp/2023_Zhu_et_al/Zhu_et_al_2023/Python_Project/ScenicPlus/Zhu_et_al

# %%
pwd
# Out:
# '/fast/AG_Bunina/Yusuf/Project_Endothelial_and_Stroke/Datasets/Chromatin_and_Gene_Exp/2023_Zhu_et_al/Zhu_et_al_2023/Python_Project/ScenicPlus/Zhu_et_al'

# %%
import numpy as np
import pandas as pd

import scanpy as sc
import episcanpy as epi
import anndata as ad

import matplotlib.pyplot as plt

import time
import pickle
import os

# %%
adata = ad.read("adata_subset_7269_cells.h5ad")

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 7269 × 302955
#     obs: 'author_cell_type', 'age_group', 'donor_id', 'nCount_RNA', 'nFeature_RNA', 'nCount_ATAC', 'nFeature_ATAC', 'TSS_percentile', 'nucleosome_signal', 'percent_mt', 'assay_ontology_term_id', 'cell_type_ontology_term_id', 'development_stage_ontology_term_id', 'disease_ontology_term_id', 'self_reported_ethnicity_ontology_term_id', 'organism_ontology_term_id', 'sex_ontology_term_id', 'tissue_ontology_term_id', 'suspension_type', 'is_primary_data', 'batch', 'tissue_type', 'cell_type', 'assay', 'disease', 'organism', 'sex', 'tissue', 'self_reported_ethnicity', 'development_stage', 'observation_joinid'
#     uns: 'author_cell_type_colors', 'batch_condition', 'citation', 'schema_reference', 'schema_version', 'title'
#     obsm: 'X_joint_wnn_umap', 'X_umap'

# %%
print("Max before:\t{}".format(np.max(adata.X)))
epi.pp.binarize(adata)
print("Max after:\t{}".format(np.max(adata.X)))
# Out:
# Max before:	29
# Max after:	1

# %%
epi.pp.qc_stats(adata, verbose=True)
# Out:
# added keys n_cells, log_n_cells to .var
# added keys n_features, log_n_features to .obs

# %%
epi.pp.highly_variable(adata, min_score=0.515, n_features=None)

# %%
adata = epi.pp.select_highly_variable(adata, verbose=True)
# Out:
# 60027 of 302955 features remain (-242928)

# %%
# save the object:

# %%
adata.write_h5ad("adata_subset_filtered_by_variability.h5ad", compression=True)

# %%
import session_info

# %%
session_info.show()
# Out:
# <details>
# <summary>Click to view session information</summary>
# <pre>
# -----
# anndata             0.9.2
# episcanpy           0.4.0
# matplotlib          3.7.2
# numpy               1.24.3
# pandas              2.0.3
# scanpy              1.9.8
# session_info        1.0.0
# -----
# </pre>
# <details>
# <summary>Click to view modules imported as dependencies</summary>
# <pre>
# PIL                 10.2.0
# asttokens           NA
# backcall            0.2.0
# bamnostic           NA
# beta_ufunc          NA
# binom_ufunc         NA
# bottleneck          1.3.7
# colorama            0.4.6
# comm                0.2.1
# cycler              0.10.0
# cython_runtime      NA
# dateutil            2.8.2
# debugpy             1.6.7
# decorator           5.1.1
# executing           0.8.3
# h5py                3.8.0
# hypergeom_ufunc     NA
# igraph              0.11.4
# importlib_metadata  NA
# importlib_resources NA
# intervaltree        NA
# invgauss_ufunc      NA
# ...

# %%
pwd
# Out:
# '/fast/AG_Bunina/Yusuf/Project_Endothelial_and_Stroke/Datasets/Chromatin_and_Gene_Exp/2023_Zhu_et_al/Zhu_et_al_2023/Python_Project/ScenicPlus/Zhu_et_al'
