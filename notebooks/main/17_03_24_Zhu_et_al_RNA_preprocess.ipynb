# %%
#supress warnings
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
import sys
import os
_stderr = sys.stderr
null = open(os.devnull,'wb')

# %%
pwd
# Out:
# '/fast/AG_Bunina/Yusuf/jobs'

# %%
cd '/fast/AG_Bunina/Yusuf/Project_Endothelial_and_Stroke/Datasets/Chromatin_and_Gene_Exp/2023_Zhu_et_al/Zhu_et_al_2023/Python_Project/ScenicPlus/Zhu_et_al'
# Out:
# /fast/AG_Bunina/Yusuf/Project_Endothelial_and_Stroke/Datasets/Chromatin_and_Gene_Exp/2023_Zhu_et_al/Zhu_et_al_2023/Python_Project/ScenicPlus/Zhu_et_al

# %%
# !mkdir -p Zhu_et_al/data

# %%
import os
work_dir = 'Zhu_et_al'

# %%
import scanpy as sc
#set some figure parameters for nice display inside jupyternotebooks.
# %matplotlib inline
sc.settings.set_figure_params(dpi=80, frameon=False, figsize=(5, 5), facecolor='white')

#make a directory for to store the processed scRNA-seq data.
if not os.path.exists(os.path.join(work_dir, 'scRNA')):
    os.makedirs(os.path.join(work_dir, 'scRNA'))

# %%
import scanpy as sc
adata = sc.read_h5ad(os.path.join(work_dir, 'data/10x_scRNA-seq_from_human_cortex.h5ad'))

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 45549 × 30113
#     obs: 'author_cell_type', 'age_group', 'donor_id', 'nCount_RNA', 'nFeature_RNA', 'nCount_ATAC', 'nFeature_ATAC', 'TSS_percentile', 'nucleosome_signal', 'percent_mt', 'assay_ontology_term_id', 'cell_type_ontology_term_id', 'development_stage_ontology_term_id', 'disease_ontology_term_id', 'self_reported_ethnicity_ontology_term_id', 'organism_ontology_term_id', 'sex_ontology_term_id', 'tissue_ontology_term_id', 'suspension_type', 'is_primary_data', 'batch', 'tissue_type', 'cell_type', 'assay', 'disease', 'organism', 'sex', 'tissue', 'self_reported_ethnicity', 'development_stage', 'observation_joinid'
#     var: 'feature_is_filtered', 'feature_name', 'feature_reference', 'feature_biotype', 'feature_length'
#     uns: 'batch_condition', 'citation', 'schema_reference', 'schema_version', 'title'
#     obsm: 'X_joint_wnn_umap', 'X_umap'

# %%
adata.obs   ## metada for cells.
# Out:
#                            author_cell_type   age_group donor_id  nCount_RNA  \
# index
# 4_AAACAGCCAACACTTG-1          EN-fetal-late  late fetal   LaFet1        3483
# 4_AAACAGCCACCAAAGG-1          EN-fetal-late  late fetal   LaFet1        4863
# 4_AAACAGCCATAAGTTC-1          EN-fetal-late  late fetal   LaFet1       11069
# 4_AAACATGCATAGTCAT-1          EN-fetal-late  late fetal   LaFet1        7990
# 4_AAACATGCATTGTCAG-1          EN-fetal-late  late fetal   LaFet1        6873
# ...                                     ...         ...      ...         ...
# 150666_TTTGTGAAGACAACAG-1  Oligodendrocytes   adulthood   Adult1         926
# 150666_TTTGTGAAGGCTGTGC-1               OPC   adulthood   Adult1        1578
# 150666_TTTGTGAAGTAAGAAC-1  Oligodendrocytes   adulthood   Adult1         352
# 150666_TTTGTGAAGTCTTGAA-1  Oligodendrocytes   adulthood   Adult1        1676
# 150666_TTTGTTGGTGATCAGC-1  Oligodendrocytes   adulthood   Adult1        2619
#
#                            nFeature_RNA  nCount_ATAC  nFeature_ATAC  \
# index
# 4_AAACAGCCAACACTTG-1             1685.0       4518.0         4024.0
# 4_AAACAGCCACCAAAGG-1             2149.0       4641.0         4128.0
# 4_AAACAGCCATAAGTTC-1             3707.0      12512.0        10169.0
# 4_AAACATGCATAGTCAT-1             2919.0       5437.0         4844.0
# 4_AAACATGCATTGTCAG-1             2652.0       5268.0         4626.0
# ...                                 ...          ...            ...
# 150666_TTTGTGAAGACAACAG-1         545.0       6654.0         5913.0
# 150666_TTTGTGAAGGCTGTGC-1        1023.0       5996.0         5311.0
# 150666_TTTGTGAAGTAAGAAC-1         303.0       4787.0         4226.0
# 150666_TTTGTGAAGTCTTGAA-1        1028.0       3336.0         2957.0
# 150666_TTTGTTGGTGATCAGC-1        1452.0       7260.0         6286.0
#
#                            TSS_percentile  nucleosome_signal  percent_mt  ...  \
# index                                                                     ...
# 4_AAACAGCCAACACTTG-1                 0.31           1.103503    0.000000  ...
# 4_AAACAGCCACCAAAGG-1                 0.72           1.002789    0.000000  ...
# 4_AAACAGCCATAAGTTC-1                 0.51           1.054060    0.000000  ...
# 4_AAACATGCATAGTCAT-1                 0.47           1.141570    0.000000  ...
# 4_AAACATGCATTGTCAG-1                 0.48           1.137788    0.021418  ...
# ...                                   ...                ...         ...  ...
# 150666_TTTGTGAAGACAACAG-1            0.34           1.029844    1.500938  ...
# 150666_TTTGTGAAGGCTGTGC-1            0.03           0.712973    0.121433  ...
# 150666_TTTGTGAAGTAAGAAC-1            0.44           1.304045    0.939702  ...
# 150666_TTTGTGAAGTCTTGAA-1            0.25           0.715888    0.119617  ...
# 150666_TTTGTTGGTGATCAGC-1            0.50           0.932277    0.644405  ...
#
#                           tissue_type                       cell_type  \
# index
# 4_AAACAGCCAACACTTG-1           tissue            glutamatergic neuron
# 4_AAACAGCCACCAAAGG-1           tissue            glutamatergic neuron
# 4_AAACAGCCATAAGTTC-1           tissue            glutamatergic neuron
# 4_AAACATGCATAGTCAT-1           tissue            glutamatergic neuron
# 4_AAACATGCATTGTCAG-1           tissue            glutamatergic neuron
# ...                               ...                             ...
# 150666_TTTGTGAAGACAACAG-1      tissue                 oligodendrocyte
# 150666_TTTGTGAAGGCTGTGC-1      tissue  oligodendrocyte precursor cell
# 150666_TTTGTGAAGTAAGAAC-1      tissue                 oligodendrocyte
# 150666_TTTGTGAAGTCTTGAA-1      tissue                 oligodendrocyte
# 150666_TTTGTTGGTGATCAGC-1      tissue                 oligodendrocyte
#
#                                   assay disease      organism     sex  \
# index
# 4_AAACAGCCAACACTTG-1       10x multiome  normal  Homo sapiens    male
# 4_AAACAGCCACCAAAGG-1       10x multiome  normal  Homo sapiens    male
# 4_AAACAGCCATAAGTTC-1       10x multiome  normal  Homo sapiens    male
# 4_AAACATGCATAGTCAT-1       10x multiome  normal  Homo sapiens    male
# 4_AAACATGCATTGTCAG-1       10x multiome  normal  Homo sapiens    male
# ...                                 ...     ...           ...     ...
# 150666_TTTGTGAAGACAACAG-1  10x multiome  normal  Homo sapiens  female
# 150666_TTTGTGAAGGCTGTGC-1  10x multiome  normal  Homo sapiens  female
# 150666_TTTGTGAAGTAAGAAC-1  10x multiome  normal  Homo sapiens  female
# 150666_TTTGTGAAGTCTTGAA-1  10x multiome  normal  Homo sapiens  female
# 150666_TTTGTTGGTGATCAGC-1  10x multiome  normal  Homo sapiens  female
#
#                                                    tissue  \
# index
# 4_AAACAGCCAACACTTG-1                       cortical plate
# 4_AAACAGCCACCAAAGG-1                       cortical plate
# 4_AAACAGCCATAAGTTC-1                       cortical plate
# 4_AAACATGCATAGTCAT-1                       cortical plate
# 4_AAACATGCATTGTCAG-1                       cortical plate
# ...                                                   ...
# 150666_TTTGTGAAGACAACAG-1  dorsolateral prefrontal cortex
# 150666_TTTGTGAAGGCTGTGC-1  dorsolateral prefrontal cortex
# 150666_TTTGTGAAGTAAGAAC-1  dorsolateral prefrontal cortex
# 150666_TTTGTGAAGTCTTGAA-1  dorsolateral prefrontal cortex
# 150666_TTTGTTGGTGATCAGC-1  dorsolateral prefrontal cortex
#
#                           self_reported_ethnicity  \
# index
# 4_AAACAGCCAACACTTG-1                      unknown
# 4_AAACAGCCACCAAAGG-1                      unknown
# 4_AAACAGCCATAAGTTC-1                      unknown
# 4_AAACATGCATAGTCAT-1                      unknown
# 4_AAACATGCATTGTCAG-1                      unknown
# ...                                           ...
# 150666_TTTGTGAAGACAACAG-1                 unknown
# 150666_TTTGTGAAGGCTGTGC-1                 unknown
# 150666_TTTGTGAAGTAAGAAC-1                 unknown
# 150666_TTTGTGAAGTCTTGAA-1                 unknown
# 150666_TTTGTTGGTGATCAGC-1                 unknown
#
#                                                   development_stage  \
# index
# 4_AAACAGCCAACACTTG-1       23rd week post-fertilization human stage
# 4_AAACAGCCACCAAAGG-1       23rd week post-fertilization human stage
# 4_AAACAGCCATAAGTTC-1       23rd week post-fertilization human stage
# 4_AAACATGCATAGTCAT-1       23rd week post-fertilization human stage
# 4_AAACATGCATTGTCAG-1       23rd week post-fertilization human stage
# ...                                                             ...
# 150666_TTTGTGAAGACAACAG-1                   20-year-old human stage
# 150666_TTTGTGAAGGCTGTGC-1                   20-year-old human stage
# 150666_TTTGTGAAGTAAGAAC-1                   20-year-old human stage
# 150666_TTTGTGAAGTCTTGAA-1                   20-year-old human stage
# 150666_TTTGTTGGTGATCAGC-1                   20-year-old human stage
#
#                            observation_joinid
# index
# 4_AAACAGCCAACACTTG-1               t<2(H>sg#K
# 4_AAACAGCCACCAAAGG-1               HPU?^1i&Yf
# 4_AAACAGCCATAAGTTC-1               vKJ1WULiG^
# 4_AAACATGCATAGTCAT-1               FE0>j_!1Tq
# 4_AAACATGCATTGTCAG-1               3sotId$RTP
# ...                                       ...
# 150666_TTTGTGAAGACAACAG-1          =x`E$@Xdkm
# 150666_TTTGTGAAGGCTGTGC-1          #bnI9b>C>}
# 150666_TTTGTGAAGTAAGAAC-1          mN;XZnza^;
# 150666_TTTGTGAAGTCTTGAA-1          k#NQ|;U)%U
# 150666_TTTGTTGGTGATCAGC-1          PNiP^>UM6e
#
# [45549 rows x 31 columns]

# %%
adata.var
# Out:
#                  feature_is_filtered       feature_name feature_reference  \
# gene_ids
# ENSG00000238009                False       RP11-34P13.7    NCBITaxon:9606
# ENSG00000241860                False      RP11-34P13.13    NCBITaxon:9606
# ENSG00000229905                False      RP11-206L10.4    NCBITaxon:9606
# ENSG00000237491                False          LINC01409    NCBITaxon:9606
# ENSG00000177757                False             FAM87B    NCBITaxon:9606
# ...                              ...                ...               ...
# ENSG00000273748                False  ENSG00000273748.1    NCBITaxon:9606
# ENSG00000271254                False  ENSG00000271254.6    NCBITaxon:9606
# ENSG00000276345                False  ENSG00000276345.1    NCBITaxon:9606
# ENSG00000278817                False  ENSG00000278817.1    NCBITaxon:9606
# ENSG00000277196                False  ENSG00000277196.4    NCBITaxon:9606
#
#                 feature_biotype feature_length
# gene_ids
# ENSG00000238009            gene           3726
# ENSG00000241860            gene           7559
# ENSG00000229905            gene            456
# ENSG00000237491            gene           8413
# ENSG00000177757            gene           1947
# ...                         ...            ...
# ENSG00000273748            gene            372
# ENSG00000271254            gene           4520
# ENSG00000276345            gene            740
# ENSG00000278817            gene           1213
# ENSG00000277196            gene           2405
#
# [30113 rows x 5 columns]

# %%
adata.obsm['X_umap'].shape
# Out:
# (45549, 2)

# %%
adata.var.shape
# Out:
# (30113, 5)

# %%
adata.var_names
# Out:
# Index(['ENSG00000238009', 'ENSG00000241860', 'ENSG00000229905',
#        'ENSG00000237491', 'ENSG00000177757', 'ENSG00000228794',
#        'ENSG00000225880', 'ENSG00000230368', 'ENSG00000272438',
#        'ENSG00000230699',
#        ...
#        'ENSG00000274847', 'ENSG00000276256', 'ENSG00000278198',
#        'ENSG00000273496', 'ENSG00000278384', 'ENSG00000273748',
#        'ENSG00000271254', 'ENSG00000276345', 'ENSG00000278817',
#        'ENSG00000277196'],
#       dtype='object', name='gene_ids', length=30113)

# %%
import numpy as np

# %%
np.unique(adata.var_names, return_counts=True)
# Out:
# (array(['ENSG00000000003', 'ENSG00000000005', 'ENSG00000000419', ...,
#         'ENSG00000288253', 'ENSG00000288321', 'ENSG00000288398'],
#        dtype=object),
#  array([1, 1, 1, ..., 1, 1, 1]))

# %%
var_names_unique, counts = np.unique(adata.var_names, return_counts=True)

# %%
var_names_unique
# Out:
# array(['ENSG00000000003', 'ENSG00000000005', 'ENSG00000000419', ...,
#        'ENSG00000288253', 'ENSG00000288321', 'ENSG00000288398'],
#       dtype=object)

# %%
counts
# Out:
# array([1, 1, 1, ..., 1, 1, 1])

# %%
np.all(counts == 1)
# Out:
# True

# %%
# our gene ids are unique so there are no duplicates. In Python, we will most of the time use the functions from numpy and pandas libraries.

# %%
import pandas as pd

# %%
pd
# Out:
# <module 'pandas' from '/home/ykazci/miniconda3/envs/scenicplus/lib/python3.8/site-packages/pandas/__init__.py'>

# %%
np
# Out:
# <module 'numpy' from '/home/ykazci/miniconda3/envs/scenicplus/lib/python3.8/site-packages/numpy/__init__.py'>

# %%
len(var_names_unique)
# Out:
# 30113

# %%
sc
# Out:
# <module 'scanpy' from '/home/ykazci/miniconda3/envs/scenicplus/lib/python3.8/site-packages/scanpy/__init__.py'>

# %%
sc.pp.filter_cells(adata, min_genes=200)

# %%
sc.pp.filter_genes(adata, min_cells=3)

# %%
adata.var
# Out:
#                  feature_is_filtered       feature_name feature_reference  \
# gene_ids
# ENSG00000238009                False       RP11-34P13.7    NCBITaxon:9606
# ENSG00000241860                False      RP11-34P13.13    NCBITaxon:9606
# ENSG00000229905                False      RP11-206L10.4    NCBITaxon:9606
# ENSG00000237491                False          LINC01409    NCBITaxon:9606
# ENSG00000177757                False             FAM87B    NCBITaxon:9606
# ...                              ...                ...               ...
# ENSG00000273748                False  ENSG00000273748.1    NCBITaxon:9606
# ENSG00000271254                False  ENSG00000271254.6    NCBITaxon:9606
# ENSG00000276345                False  ENSG00000276345.1    NCBITaxon:9606
# ENSG00000278817                False  ENSG00000278817.1    NCBITaxon:9606
# ENSG00000277196                False  ENSG00000277196.4    NCBITaxon:9606
#
#                 feature_biotype feature_length  n_cells
# gene_ids
# ENSG00000238009            gene           3726      235
# ENSG00000241860            gene           7559      567
# ENSG00000229905            gene            456       26
# ENSG00000237491            gene           8413     3376
# ENSG00000177757            gene           1947       13
# ...                         ...            ...      ...
# ENSG00000273748            gene            372     8182
# ENSG00000271254            gene           4520     1047
# ENSG00000276345            gene            740       20
# ENSG00000278817            gene           1213      398
# ENSG00000277196            gene           2405      401
#
# [30109 rows x 6 columns]

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 45549 × 30109
#     obs: 'author_cell_type', 'age_group', 'donor_id', 'nCount_RNA', 'nFeature_RNA', 'nCount_ATAC', 'nFeature_ATAC', 'TSS_percentile', 'nucleosome_signal', 'percent_mt', 'assay_ontology_term_id', 'cell_type_ontology_term_id', 'development_stage_ontology_term_id', 'disease_ontology_term_id', 'self_reported_ethnicity_ontology_term_id', 'organism_ontology_term_id', 'sex_ontology_term_id', 'tissue_ontology_term_id', 'suspension_type', 'is_primary_data', 'batch', 'tissue_type', 'cell_type', 'assay', 'disease', 'organism', 'sex', 'tissue', 'self_reported_ethnicity', 'development_stage', 'observation_joinid', 'n_genes'
#     var: 'feature_is_filtered', 'feature_name', 'feature_reference', 'feature_biotype', 'feature_length', 'n_cells'
#     uns: 'batch_condition', 'citation', 'schema_reference', 'schema_version', 'title'
#     obsm: 'X_joint_wnn_umap', 'X_umap'

# %%
adata.shape # to check for dimensions.
# Out:
# (45549, 30109)

# %%
sc.external.pp.scrublet(adata) #estimates doublets
# Out:
# /home/ykazci/miniconda3/envs/scenicplus/lib/python3.8/site-packages/scanpy/preprocessing/_normalization.py:169: UserWarning: Received a view of an AnnData. Making a copy.
#   view_to_actual(adata)
# Automatically set threshold at doublet score = 0.21
# Detected doublet rate = 2.7%
# Estimated detectable doublet fraction = 68.0%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 3.9%

# %%
adata.obs
# Out:
#                            author_cell_type   age_group donor_id  nCount_RNA  \
# index
# 4_AAACAGCCAACACTTG-1          EN-fetal-late  late fetal   LaFet1        3483
# 4_AAACAGCCACCAAAGG-1          EN-fetal-late  late fetal   LaFet1        4863
# 4_AAACAGCCATAAGTTC-1          EN-fetal-late  late fetal   LaFet1       11069
# 4_AAACATGCATAGTCAT-1          EN-fetal-late  late fetal   LaFet1        7990
# 4_AAACATGCATTGTCAG-1          EN-fetal-late  late fetal   LaFet1        6873
# ...                                     ...         ...      ...         ...
# 150666_TTTGTGAAGACAACAG-1  Oligodendrocytes   adulthood   Adult1         926
# 150666_TTTGTGAAGGCTGTGC-1               OPC   adulthood   Adult1        1578
# 150666_TTTGTGAAGTAAGAAC-1  Oligodendrocytes   adulthood   Adult1         352
# 150666_TTTGTGAAGTCTTGAA-1  Oligodendrocytes   adulthood   Adult1        1676
# 150666_TTTGTTGGTGATCAGC-1  Oligodendrocytes   adulthood   Adult1        2619
#
#                            nFeature_RNA  nCount_ATAC  nFeature_ATAC  \
# index
# 4_AAACAGCCAACACTTG-1             1685.0       4518.0         4024.0
# 4_AAACAGCCACCAAAGG-1             2149.0       4641.0         4128.0
# 4_AAACAGCCATAAGTTC-1             3707.0      12512.0        10169.0
# 4_AAACATGCATAGTCAT-1             2919.0       5437.0         4844.0
# 4_AAACATGCATTGTCAG-1             2652.0       5268.0         4626.0
# ...                                 ...          ...            ...
# 150666_TTTGTGAAGACAACAG-1         545.0       6654.0         5913.0
# 150666_TTTGTGAAGGCTGTGC-1        1023.0       5996.0         5311.0
# 150666_TTTGTGAAGTAAGAAC-1         303.0       4787.0         4226.0
# 150666_TTTGTGAAGTCTTGAA-1        1028.0       3336.0         2957.0
# 150666_TTTGTTGGTGATCAGC-1        1452.0       7260.0         6286.0
#
#                            TSS_percentile  nucleosome_signal  percent_mt  ...  \
# index                                                                     ...
# 4_AAACAGCCAACACTTG-1                 0.31           1.103503    0.000000  ...
# 4_AAACAGCCACCAAAGG-1                 0.72           1.002789    0.000000  ...
# 4_AAACAGCCATAAGTTC-1                 0.51           1.054060    0.000000  ...
# 4_AAACATGCATAGTCAT-1                 0.47           1.141570    0.000000  ...
# 4_AAACATGCATTGTCAG-1                 0.48           1.137788    0.021418  ...
# ...                                   ...                ...         ...  ...
# 150666_TTTGTGAAGACAACAG-1            0.34           1.029844    1.500938  ...
# 150666_TTTGTGAAGGCTGTGC-1            0.03           0.712973    0.121433  ...
# 150666_TTTGTGAAGTAAGAAC-1            0.44           1.304045    0.939702  ...
# 150666_TTTGTGAAGTCTTGAA-1            0.25           0.715888    0.119617  ...
# 150666_TTTGTTGGTGATCAGC-1            0.50           0.932277    0.644405  ...
#
#                           disease      organism     sex  \
# index
# 4_AAACAGCCAACACTTG-1       normal  Homo sapiens    male
# 4_AAACAGCCACCAAAGG-1       normal  Homo sapiens    male
# 4_AAACAGCCATAAGTTC-1       normal  Homo sapiens    male
# 4_AAACATGCATAGTCAT-1       normal  Homo sapiens    male
# 4_AAACATGCATTGTCAG-1       normal  Homo sapiens    male
# ...                           ...           ...     ...
# 150666_TTTGTGAAGACAACAG-1  normal  Homo sapiens  female
# 150666_TTTGTGAAGGCTGTGC-1  normal  Homo sapiens  female
# 150666_TTTGTGAAGTAAGAAC-1  normal  Homo sapiens  female
# 150666_TTTGTGAAGTCTTGAA-1  normal  Homo sapiens  female
# 150666_TTTGTTGGTGATCAGC-1  normal  Homo sapiens  female
#
#                                                    tissue  \
# index
# 4_AAACAGCCAACACTTG-1                       cortical plate
# 4_AAACAGCCACCAAAGG-1                       cortical plate
# 4_AAACAGCCATAAGTTC-1                       cortical plate
# 4_AAACATGCATAGTCAT-1                       cortical plate
# 4_AAACATGCATTGTCAG-1                       cortical plate
# ...                                                   ...
# 150666_TTTGTGAAGACAACAG-1  dorsolateral prefrontal cortex
# 150666_TTTGTGAAGGCTGTGC-1  dorsolateral prefrontal cortex
# 150666_TTTGTGAAGTAAGAAC-1  dorsolateral prefrontal cortex
# 150666_TTTGTGAAGTCTTGAA-1  dorsolateral prefrontal cortex
# 150666_TTTGTTGGTGATCAGC-1  dorsolateral prefrontal cortex
#
#                           self_reported_ethnicity  \
# index
# 4_AAACAGCCAACACTTG-1                      unknown
# 4_AAACAGCCACCAAAGG-1                      unknown
# 4_AAACAGCCATAAGTTC-1                      unknown
# 4_AAACATGCATAGTCAT-1                      unknown
# 4_AAACATGCATTGTCAG-1                      unknown
# ...                                           ...
# 150666_TTTGTGAAGACAACAG-1                 unknown
# 150666_TTTGTGAAGGCTGTGC-1                 unknown
# 150666_TTTGTGAAGTAAGAAC-1                 unknown
# 150666_TTTGTGAAGTCTTGAA-1                 unknown
# 150666_TTTGTTGGTGATCAGC-1                 unknown
#
#                                                   development_stage  \
# index
# 4_AAACAGCCAACACTTG-1       23rd week post-fertilization human stage
# 4_AAACAGCCACCAAAGG-1       23rd week post-fertilization human stage
# 4_AAACAGCCATAAGTTC-1       23rd week post-fertilization human stage
# 4_AAACATGCATAGTCAT-1       23rd week post-fertilization human stage
# 4_AAACATGCATTGTCAG-1       23rd week post-fertilization human stage
# ...                                                             ...
# 150666_TTTGTGAAGACAACAG-1                   20-year-old human stage
# 150666_TTTGTGAAGGCTGTGC-1                   20-year-old human stage
# 150666_TTTGTGAAGTAAGAAC-1                   20-year-old human stage
# 150666_TTTGTGAAGTCTTGAA-1                   20-year-old human stage
# 150666_TTTGTTGGTGATCAGC-1                   20-year-old human stage
#
#                           observation_joinid n_genes doublet_score  \
# index
# 4_AAACAGCCAACACTTG-1              t<2(H>sg#K    1685      0.002589
# 4_AAACAGCCACCAAAGG-1              HPU?^1i&Yf    2148      0.007228
# 4_AAACAGCCATAAGTTC-1              vKJ1WULiG^    2466      0.013963
# 4_AAACATGCATAGTCAT-1              FE0>j_!1Tq    2616      0.005489
# 4_AAACATGCATTGTCAG-1              3sotId$RTP    2594      0.003706
# ...                                      ...     ...           ...
# 150666_TTTGTGAAGACAACAG-1         =x`E$@Xdkm     841      0.020478
# 150666_TTTGTGAAGGCTGTGC-1         #bnI9b>C>}    1040      0.034496
# 150666_TTTGTGAAGTAAGAAC-1         mN;XZnza^;    1083      0.006090
# 150666_TTTGTGAAGTCTTGAA-1         k#NQ|;U)%U    1046      0.009910
# 150666_TTTGTTGGTGATCAGC-1         PNiP^>UM6e    1452      0.006212
#
#                            predicted_doublet
# index
# 4_AAACAGCCAACACTTG-1                   False
# 4_AAACAGCCACCAAAGG-1                   False
# 4_AAACAGCCATAAGTTC-1                   False
# 4_AAACATGCATAGTCAT-1                   False
# 4_AAACATGCATTGTCAG-1                   False
# ...                                      ...
# 150666_TTTGTGAAGACAACAG-1              False
# 150666_TTTGTGAAGGCTGTGC-1              False
# 150666_TTTGTGAAGTAAGAAC-1              False
# 150666_TTTGTGAAGTCTTGAA-1              False
# 150666_TTTGTTGGTGATCAGC-1              False
#
# [45549 rows x 34 columns]

# %%
adata.obs['predicted_doublet']
# Out:
# index
# 4_AAACAGCCAACACTTG-1         False
# 4_AAACAGCCACCAAAGG-1         False
# 4_AAACAGCCATAAGTTC-1         False
# 4_AAACATGCATAGTCAT-1         False
# 4_AAACATGCATTGTCAG-1         False
#                              ...
# 150666_TTTGTGAAGACAACAG-1    False
# 150666_TTTGTGAAGGCTGTGC-1    False
# 150666_TTTGTGAAGTAAGAAC-1    False
# 150666_TTTGTGAAGTCTTGAA-1    False
# 150666_TTTGTTGGTGATCAGC-1    False
# Name: predicted_doublet, Length: 45549, dtype: bool

# %%
adata = adata[adata.obs['predicted_doublet'] == False] #do the actual filtering
adata
# Out:
# View of AnnData object with n_obs × n_vars = 44330 × 30109
#     obs: 'author_cell_type', 'age_group', 'donor_id', 'nCount_RNA', 'nFeature_RNA', 'nCount_ATAC', 'nFeature_ATAC', 'TSS_percentile', 'nucleosome_signal', 'percent_mt', 'assay_ontology_term_id', 'cell_type_ontology_term_id', 'development_stage_ontology_term_id', 'disease_ontology_term_id', 'self_reported_ethnicity_ontology_term_id', 'organism_ontology_term_id', 'sex_ontology_term_id', 'tissue_ontology_term_id', 'suspension_type', 'is_primary_data', 'batch', 'tissue_type', 'cell_type', 'assay', 'disease', 'organism', 'sex', 'tissue', 'self_reported_ethnicity', 'development_stage', 'observation_joinid', 'n_genes', 'doublet_score', 'predicted_doublet'
#     var: 'feature_is_filtered', 'feature_name', 'feature_reference', 'feature_biotype', 'feature_length', 'n_cells'
#     uns: 'batch_condition', 'citation', 'schema_reference', 'schema_version', 'title', 'scrublet'
#     obsm: 'X_joint_wnn_umap', 'X_umap'

# %%
adata.var["feature_name"].str.startswith('MT-').value_counts() # Check mitochondrial feature names:
# Out:
# feature_name
# False    30096
# True        13
# Name: count, dtype: int64

# %%
adata.var['mt'] = adata.var["feature_name"].str.startswith('MT-')  # annotate the group of mitochondrial genes as 'mt'
sc.pp.calculate_qc_metrics(adata, qc_vars=['mt'], percent_top=None, log1p=False, inplace=True)
import matplotlib.pyplot as plt
mito_filter = 25
n_counts_filter = 4300
fig, axs = plt.subplots(ncols = 2, figsize = (8,4))
sc.pl.scatter(adata, x='total_counts', y='pct_counts_mt', ax = axs[0], show=False)
sc.pl.scatter(adata, x='total_counts', y='n_genes_by_counts', ax = axs[1], show = False)
#draw horizontal red lines indicating thresholds.
axs[0].hlines(y = mito_filter, xmin = 0, xmax = max(adata.obs['total_counts']), color = 'red', ls = 'dashed')
axs[1].hlines(y = n_counts_filter, xmin = 0, xmax = max(adata.obs['total_counts']), color = 'red', ls = 'dashed')
fig.tight_layout()
plt.show()
# Out:
# /tmp/7021186.1.all.q/ipykernel_35122/1529237522.py:1: ImplicitModificationWarning: Trying to modify attribute `.var` of view, initializing view as actual.
#   adata.var['mt'] = adata.var["feature_name"].str.startswith('MT-')  # annotate the group of mitochondrial genes as 'mt'

# %%
adata.var["mt"].value_counts()  # check if it is correctly added.
# Out:
# mt
# False    30096
# True        13
# Name: count, dtype: int64

# %%
adata.var['mt']
# Out:
# gene_ids
# ENSG00000238009    False
# ENSG00000241860    False
# ENSG00000229905    False
# ENSG00000237491    False
# ENSG00000177757    False
#                    ...
# ENSG00000273748    False
# ENSG00000271254    False
# ENSG00000276345    False
# ENSG00000278817    False
# ENSG00000277196    False
# Name: mt, Length: 30109, dtype: bool

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 44330 × 30109
#     obs: 'author_cell_type', 'age_group', 'donor_id', 'nCount_RNA', 'nFeature_RNA', 'nCount_ATAC', 'nFeature_ATAC', 'TSS_percentile', 'nucleosome_signal', 'percent_mt', 'assay_ontology_term_id', 'cell_type_ontology_term_id', 'development_stage_ontology_term_id', 'disease_ontology_term_id', 'self_reported_ethnicity_ontology_term_id', 'organism_ontology_term_id', 'sex_ontology_term_id', 'tissue_ontology_term_id', 'suspension_type', 'is_primary_data', 'batch', 'tissue_type', 'cell_type', 'assay', 'disease', 'organism', 'sex', 'tissue', 'self_reported_ethnicity', 'development_stage', 'observation_joinid', 'n_genes', 'doublet_score', 'predicted_doublet', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt'
#     var: 'feature_is_filtered', 'feature_name', 'feature_reference', 'feature_biotype', 'feature_length', 'n_cells', 'mt', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts'
#     uns: 'batch_condition', 'citation', 'schema_reference', 'schema_version', 'title', 'scrublet'
#     obsm: 'X_joint_wnn_umap', 'X_umap'

# %%
# Below the data will be normalized and scaled. This is only for visualization purposes. For the actual SCENIC+ analysis we will use the raw count matrix. For this reason we save the non-normalized and non-scaled AnnData object in the raw slot before carying on.

# %%
adata.raw = adata # keep to use in scenicplus object.
sc.pp.normalize_total(adata, target_sum=1e4)
sc.pp.log1p(adata)
sc.pp.highly_variable_genes(adata, min_mean=0.0125, max_mean=3, min_disp=0.5)

# Here, in PBMC tutorial, the genes are subsetted into highly variable ones. However, they do not do this in human cerebellum tutorial.
# I will not do this here.
# adata = adata[:, adata.var.highly_variable] # Here, 
sc.pp.scale(adata, max_value=10)

# %%
adata.obs
# Out:
#                            author_cell_type   age_group donor_id  nCount_RNA  \
# index
# 4_AAACAGCCAACACTTG-1          EN-fetal-late  late fetal   LaFet1        3483
# 4_AAACAGCCACCAAAGG-1          EN-fetal-late  late fetal   LaFet1        4863
# 4_AAACAGCCATAAGTTC-1          EN-fetal-late  late fetal   LaFet1       11069
# 4_AAACATGCATAGTCAT-1          EN-fetal-late  late fetal   LaFet1        7990
# 4_AAACATGCATTGTCAG-1          EN-fetal-late  late fetal   LaFet1        6873
# ...                                     ...         ...      ...         ...
# 150666_TTTGTGAAGACAACAG-1  Oligodendrocytes   adulthood   Adult1         926
# 150666_TTTGTGAAGGCTGTGC-1               OPC   adulthood   Adult1        1578
# 150666_TTTGTGAAGTAAGAAC-1  Oligodendrocytes   adulthood   Adult1         352
# 150666_TTTGTGAAGTCTTGAA-1  Oligodendrocytes   adulthood   Adult1        1676
# 150666_TTTGTTGGTGATCAGC-1  Oligodendrocytes   adulthood   Adult1        2619
#
#                            nFeature_RNA  nCount_ATAC  nFeature_ATAC  \
# index
# 4_AAACAGCCAACACTTG-1             1685.0       4518.0         4024.0
# 4_AAACAGCCACCAAAGG-1             2149.0       4641.0         4128.0
# 4_AAACAGCCATAAGTTC-1             3707.0      12512.0        10169.0
# 4_AAACATGCATAGTCAT-1             2919.0       5437.0         4844.0
# 4_AAACATGCATTGTCAG-1             2652.0       5268.0         4626.0
# ...                                 ...          ...            ...
# 150666_TTTGTGAAGACAACAG-1         545.0       6654.0         5913.0
# 150666_TTTGTGAAGGCTGTGC-1        1023.0       5996.0         5311.0
# 150666_TTTGTGAAGTAAGAAC-1         303.0       4787.0         4226.0
# 150666_TTTGTGAAGTCTTGAA-1        1028.0       3336.0         2957.0
# 150666_TTTGTTGGTGATCAGC-1        1452.0       7260.0         6286.0
#
#                            TSS_percentile  nucleosome_signal  percent_mt  ...  \
# index                                                                     ...
# 4_AAACAGCCAACACTTG-1                 0.31           1.103503    0.000000  ...
# 4_AAACAGCCACCAAAGG-1                 0.72           1.002789    0.000000  ...
# 4_AAACAGCCATAAGTTC-1                 0.51           1.054060    0.000000  ...
# 4_AAACATGCATAGTCAT-1                 0.47           1.141570    0.000000  ...
# 4_AAACATGCATTGTCAG-1                 0.48           1.137788    0.021418  ...
# ...                                   ...                ...         ...  ...
# 150666_TTTGTGAAGACAACAG-1            0.34           1.029844    1.500938  ...
# 150666_TTTGTGAAGGCTGTGC-1            0.03           0.712973    0.121433  ...
# 150666_TTTGTGAAGTAAGAAC-1            0.44           1.304045    0.939702  ...
# 150666_TTTGTGAAGTCTTGAA-1            0.25           0.715888    0.119617  ...
# 150666_TTTGTTGGTGATCAGC-1            0.50           0.932277    0.644405  ...
#
#                           self_reported_ethnicity  \
# index
# 4_AAACAGCCAACACTTG-1                      unknown
# 4_AAACAGCCACCAAAGG-1                      unknown
# 4_AAACAGCCATAAGTTC-1                      unknown
# 4_AAACATGCATAGTCAT-1                      unknown
# 4_AAACATGCATTGTCAG-1                      unknown
# ...                                           ...
# 150666_TTTGTGAAGACAACAG-1                 unknown
# 150666_TTTGTGAAGGCTGTGC-1                 unknown
# 150666_TTTGTGAAGTAAGAAC-1                 unknown
# 150666_TTTGTGAAGTCTTGAA-1                 unknown
# 150666_TTTGTTGGTGATCAGC-1                 unknown
#
#                                                   development_stage  \
# index
# 4_AAACAGCCAACACTTG-1       23rd week post-fertilization human stage
# 4_AAACAGCCACCAAAGG-1       23rd week post-fertilization human stage
# 4_AAACAGCCATAAGTTC-1       23rd week post-fertilization human stage
# 4_AAACATGCATAGTCAT-1       23rd week post-fertilization human stage
# 4_AAACATGCATTGTCAG-1       23rd week post-fertilization human stage
# ...                                                             ...
# 150666_TTTGTGAAGACAACAG-1                   20-year-old human stage
# 150666_TTTGTGAAGGCTGTGC-1                   20-year-old human stage
# 150666_TTTGTGAAGTAAGAAC-1                   20-year-old human stage
# 150666_TTTGTGAAGTCTTGAA-1                   20-year-old human stage
# 150666_TTTGTTGGTGATCAGC-1                   20-year-old human stage
#
#                           observation_joinid n_genes doublet_score  \
# index
# 4_AAACAGCCAACACTTG-1              t<2(H>sg#K    1685      0.002589
# 4_AAACAGCCACCAAAGG-1              HPU?^1i&Yf    2148      0.007228
# 4_AAACAGCCATAAGTTC-1              vKJ1WULiG^    2466      0.013963
# 4_AAACATGCATAGTCAT-1              FE0>j_!1Tq    2616      0.005489
# 4_AAACATGCATTGTCAG-1              3sotId$RTP    2594      0.003706
# ...                                      ...     ...           ...
# 150666_TTTGTGAAGACAACAG-1         =x`E$@Xdkm     841      0.020478
# 150666_TTTGTGAAGGCTGTGC-1         #bnI9b>C>}    1040      0.034496
# 150666_TTTGTGAAGTAAGAAC-1         mN;XZnza^;    1083      0.006090
# 150666_TTTGTGAAGTCTTGAA-1         k#NQ|;U)%U    1046      0.009910
# 150666_TTTGTTGGTGATCAGC-1         PNiP^>UM6e    1452      0.006212
#
#                           predicted_doublet n_genes_by_counts total_counts  \
# index
# 4_AAACAGCCAACACTTG-1                  False              1685  1595.391724
# 4_AAACAGCCACCAAAGG-1                  False              2148  2047.995728
# 4_AAACAGCCATAAGTTC-1                  False              2466  2177.337646
# 4_AAACATGCATAGTCAT-1                  False              2616  2301.708252
# 4_AAACATGCATTGTCAG-1                  False              2594  2252.297119
# ...                                     ...               ...          ...
# 150666_TTTGTGAAGACAACAG-1             False               841   953.665894
# 150666_TTTGTGAAGGCTGTGC-1             False              1040  1352.420288
# 150666_TTTGTGAAGTAAGAAC-1             False              1083  1098.090942
# 150666_TTTGTGAAGTCTTGAA-1             False              1046  1342.691650
# 150666_TTTGTTGGTGATCAGC-1             False              1452  1476.972900
#
#                           total_counts_mt  pct_counts_mt
# index
# 4_AAACAGCCAACACTTG-1             0.000000       0.000000
# 4_AAACAGCCACCAAAGG-1             0.000000       0.000000
# 4_AAACAGCCATAAGTTC-1             0.000000       0.000000
# 4_AAACATGCATAGTCAT-1             0.000000       0.000000
# 4_AAACATGCATTGTCAG-1             0.693147       0.030775
# ...                                   ...            ...
# 150666_TTTGTGAAGACAACAG-1       13.847195       1.451996
# 150666_TTTGTGAAGGCTGTGC-1        1.609438       0.119004
# 150666_TTTGTGAAGTAAGAAC-1        6.802395       0.619475
# 150666_TTTGTGAAGTCTTGAA-1        2.197225       0.163643
# 150666_TTTGTTGGTGATCAGC-1       10.373491       0.702348
#
# [44330 rows x 38 columns]

# %%
sc.pl.embedding(adata, color = 'author_cell_type', basis='X_joint_wnn_umap')
# Out:
# /home/ykazci/miniconda3/envs/scenicplus/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:394: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(

# %%
sc.pl.embedding(adata, color = 'author_cell_type', basis='X_umap')
# Out:
# /home/ykazci/miniconda3/envs/scenicplus/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:394: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(

# %%
sc.tl.pca(adata, svd_solver="arpack")

# %%
sc.pl.pca(adata, color='author_cell_type')
# Out:
# /home/ykazci/miniconda3/envs/scenicplus/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:394: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(

# %%
adata.obs["author_cell_type"]
# Out:
# index
# 4_AAACAGCCAACACTTG-1            EN-fetal-late
# 4_AAACAGCCACCAAAGG-1            EN-fetal-late
# 4_AAACAGCCATAAGTTC-1            EN-fetal-late
# 4_AAACATGCATAGTCAT-1            EN-fetal-late
# 4_AAACATGCATTGTCAG-1            EN-fetal-late
#                                    ...
# 150666_TTTGTGAAGACAACAG-1    Oligodendrocytes
# 150666_TTTGTGAAGGCTGTGC-1                 OPC
# 150666_TTTGTGAAGTAAGAAC-1    Oligodendrocytes
# 150666_TTTGTGAAGTCTTGAA-1    Oligodendrocytes
# 150666_TTTGTTGGTGATCAGC-1    Oligodendrocytes
# Name: author_cell_type, Length: 44330, dtype: category
# Categories (15, object): ['Astrocytes', 'EN', 'EN-fetal-early', 'EN-fetal-late', ..., 'Oligodendrocytes', 'Pericytes', 'RG', 'VSMC']

# %%
adata.obs["age_group"]
# Out:
# index
# 4_AAACAGCCAACACTTG-1         late fetal
# 4_AAACAGCCACCAAAGG-1         late fetal
# 4_AAACAGCCATAAGTTC-1         late fetal
# 4_AAACATGCATAGTCAT-1         late fetal
# 4_AAACATGCATTGTCAG-1         late fetal
#                                 ...
# 150666_TTTGTGAAGACAACAG-1     adulthood
# 150666_TTTGTGAAGGCTGTGC-1     adulthood
# 150666_TTTGTGAAGTAAGAAC-1     adulthood
# 150666_TTTGTGAAGTCTTGAA-1     adulthood
# 150666_TTTGTTGGTGATCAGC-1     adulthood
# Name: age_group, Length: 44330, dtype: category
# Categories (6, object): ['adolescence', 'adulthood', 'childhood', 'early fetal', 'infancy', 'late fetal']

# %%
adata.obs['celltype'] = adata.obs["author_cell_type"]

# %%
adata.obs
# Out:
#                            author_cell_type   age_group donor_id  nCount_RNA  \
# index
# 4_AAACAGCCAACACTTG-1          EN-fetal-late  late fetal   LaFet1        3483
# 4_AAACAGCCACCAAAGG-1          EN-fetal-late  late fetal   LaFet1        4863
# 4_AAACAGCCATAAGTTC-1          EN-fetal-late  late fetal   LaFet1       11069
# 4_AAACATGCATAGTCAT-1          EN-fetal-late  late fetal   LaFet1        7990
# 4_AAACATGCATTGTCAG-1          EN-fetal-late  late fetal   LaFet1        6873
# ...                                     ...         ...      ...         ...
# 150666_TTTGTGAAGACAACAG-1  Oligodendrocytes   adulthood   Adult1         926
# 150666_TTTGTGAAGGCTGTGC-1               OPC   adulthood   Adult1        1578
# 150666_TTTGTGAAGTAAGAAC-1  Oligodendrocytes   adulthood   Adult1         352
# 150666_TTTGTGAAGTCTTGAA-1  Oligodendrocytes   adulthood   Adult1        1676
# 150666_TTTGTTGGTGATCAGC-1  Oligodendrocytes   adulthood   Adult1        2619
#
#                            nFeature_RNA  nCount_ATAC  nFeature_ATAC  \
# index
# 4_AAACAGCCAACACTTG-1             1685.0       4518.0         4024.0
# 4_AAACAGCCACCAAAGG-1             2149.0       4641.0         4128.0
# 4_AAACAGCCATAAGTTC-1             3707.0      12512.0        10169.0
# 4_AAACATGCATAGTCAT-1             2919.0       5437.0         4844.0
# 4_AAACATGCATTGTCAG-1             2652.0       5268.0         4626.0
# ...                                 ...          ...            ...
# 150666_TTTGTGAAGACAACAG-1         545.0       6654.0         5913.0
# 150666_TTTGTGAAGGCTGTGC-1        1023.0       5996.0         5311.0
# 150666_TTTGTGAAGTAAGAAC-1         303.0       4787.0         4226.0
# 150666_TTTGTGAAGTCTTGAA-1        1028.0       3336.0         2957.0
# 150666_TTTGTTGGTGATCAGC-1        1452.0       7260.0         6286.0
#
#                            TSS_percentile  nucleosome_signal  percent_mt  ...  \
# index                                                                     ...
# 4_AAACAGCCAACACTTG-1                 0.31           1.103503    0.000000  ...
# 4_AAACAGCCACCAAAGG-1                 0.72           1.002789    0.000000  ...
# 4_AAACAGCCATAAGTTC-1                 0.51           1.054060    0.000000  ...
# 4_AAACATGCATAGTCAT-1                 0.47           1.141570    0.000000  ...
# 4_AAACATGCATTGTCAG-1                 0.48           1.137788    0.021418  ...
# ...                                   ...                ...         ...  ...
# 150666_TTTGTGAAGACAACAG-1            0.34           1.029844    1.500938  ...
# 150666_TTTGTGAAGGCTGTGC-1            0.03           0.712973    0.121433  ...
# 150666_TTTGTGAAGTAAGAAC-1            0.44           1.304045    0.939702  ...
# 150666_TTTGTGAAGTCTTGAA-1            0.25           0.715888    0.119617  ...
# 150666_TTTGTTGGTGATCAGC-1            0.50           0.932277    0.644405  ...
#
#                                                   development_stage  \
# index
# 4_AAACAGCCAACACTTG-1       23rd week post-fertilization human stage
# 4_AAACAGCCACCAAAGG-1       23rd week post-fertilization human stage
# 4_AAACAGCCATAAGTTC-1       23rd week post-fertilization human stage
# 4_AAACATGCATAGTCAT-1       23rd week post-fertilization human stage
# 4_AAACATGCATTGTCAG-1       23rd week post-fertilization human stage
# ...                                                             ...
# 150666_TTTGTGAAGACAACAG-1                   20-year-old human stage
# 150666_TTTGTGAAGGCTGTGC-1                   20-year-old human stage
# 150666_TTTGTGAAGTAAGAAC-1                   20-year-old human stage
# 150666_TTTGTGAAGTCTTGAA-1                   20-year-old human stage
# 150666_TTTGTTGGTGATCAGC-1                   20-year-old human stage
#
#                           observation_joinid n_genes doublet_score  \
# index
# 4_AAACAGCCAACACTTG-1              t<2(H>sg#K    1685      0.002589
# 4_AAACAGCCACCAAAGG-1              HPU?^1i&Yf    2148      0.007228
# 4_AAACAGCCATAAGTTC-1              vKJ1WULiG^    2466      0.013963
# 4_AAACATGCATAGTCAT-1              FE0>j_!1Tq    2616      0.005489
# 4_AAACATGCATTGTCAG-1              3sotId$RTP    2594      0.003706
# ...                                      ...     ...           ...
# 150666_TTTGTGAAGACAACAG-1         =x`E$@Xdkm     841      0.020478
# 150666_TTTGTGAAGGCTGTGC-1         #bnI9b>C>}    1040      0.034496
# 150666_TTTGTGAAGTAAGAAC-1         mN;XZnza^;    1083      0.006090
# 150666_TTTGTGAAGTCTTGAA-1         k#NQ|;U)%U    1046      0.009910
# 150666_TTTGTTGGTGATCAGC-1         PNiP^>UM6e    1452      0.006212
#
#                           predicted_doublet n_genes_by_counts total_counts  \
# index
# 4_AAACAGCCAACACTTG-1                  False              1685  1595.391724
# 4_AAACAGCCACCAAAGG-1                  False              2148  2047.995728
# 4_AAACAGCCATAAGTTC-1                  False              2466  2177.337646
# 4_AAACATGCATAGTCAT-1                  False              2616  2301.708252
# 4_AAACATGCATTGTCAG-1                  False              2594  2252.297119
# ...                                     ...               ...          ...
# 150666_TTTGTGAAGACAACAG-1             False               841   953.665894
# 150666_TTTGTGAAGGCTGTGC-1             False              1040  1352.420288
# 150666_TTTGTGAAGTAAGAAC-1             False              1083  1098.090942
# 150666_TTTGTGAAGTCTTGAA-1             False              1046  1342.691650
# 150666_TTTGTTGGTGATCAGC-1             False              1452  1476.972900
#
#                           total_counts_mt pct_counts_mt          celltype
# index
# 4_AAACAGCCAACACTTG-1             0.000000      0.000000     EN-fetal-late
# 4_AAACAGCCACCAAAGG-1             0.000000      0.000000     EN-fetal-late
# 4_AAACAGCCATAAGTTC-1             0.000000      0.000000     EN-fetal-late
# 4_AAACATGCATAGTCAT-1             0.000000      0.000000     EN-fetal-late
# 4_AAACATGCATTGTCAG-1             0.693147      0.030775     EN-fetal-late
# ...                                   ...           ...               ...
# 150666_TTTGTGAAGACAACAG-1       13.847195      1.451996  Oligodendrocytes
# 150666_TTTGTGAAGGCTGTGC-1        1.609438      0.119004               OPC
# 150666_TTTGTGAAGTAAGAAC-1        6.802395      0.619475  Oligodendrocytes
# 150666_TTTGTGAAGTCTTGAA-1        2.197225      0.163643  Oligodendrocytes
# 150666_TTTGTTGGTGATCAGC-1       10.373491      0.702348  Oligodendrocytes
#
# [44330 rows x 39 columns]

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 44330 × 30109
#     obs: 'author_cell_type', 'age_group', 'donor_id', 'nCount_RNA', 'nFeature_RNA', 'nCount_ATAC', 'nFeature_ATAC', 'TSS_percentile', 'nucleosome_signal', 'percent_mt', 'assay_ontology_term_id', 'cell_type_ontology_term_id', 'development_stage_ontology_term_id', 'disease_ontology_term_id', 'self_reported_ethnicity_ontology_term_id', 'organism_ontology_term_id', 'sex_ontology_term_id', 'tissue_ontology_term_id', 'suspension_type', 'is_primary_data', 'batch', 'tissue_type', 'cell_type', 'assay', 'disease', 'organism', 'sex', 'tissue', 'self_reported_ethnicity', 'development_stage', 'observation_joinid', 'n_genes', 'doublet_score', 'predicted_doublet', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'celltype'
#     var: 'feature_is_filtered', 'feature_name', 'feature_reference', 'feature_biotype', 'feature_length', 'n_cells', 'mt', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts', 'highly_variable', 'means', 'dispersions', 'dispersions_norm', 'mean', 'std'
#     uns: 'batch_condition', 'citation', 'schema_reference', 'schema_version', 'title', 'scrublet', 'log1p', 'hvg', 'author_cell_type_colors', 'pca'
#     obsm: 'X_joint_wnn_umap', 'X_umap', 'X_pca'
#     varm: 'PCs'

# %%
adata.obsm['Author_UMAP'] = adata.obsm["X_umap"].copy()

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 44330 × 30109
#     obs: 'author_cell_type', 'age_group', 'donor_id', 'nCount_RNA', 'nFeature_RNA', 'nCount_ATAC', 'nFeature_ATAC', 'TSS_percentile', 'nucleosome_signal', 'percent_mt', 'assay_ontology_term_id', 'cell_type_ontology_term_id', 'development_stage_ontology_term_id', 'disease_ontology_term_id', 'self_reported_ethnicity_ontology_term_id', 'organism_ontology_term_id', 'sex_ontology_term_id', 'tissue_ontology_term_id', 'suspension_type', 'is_primary_data', 'batch', 'tissue_type', 'cell_type', 'assay', 'disease', 'organism', 'sex', 'tissue', 'self_reported_ethnicity', 'development_stage', 'observation_joinid', 'n_genes', 'doublet_score', 'predicted_doublet', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'celltype'
#     var: 'feature_is_filtered', 'feature_name', 'feature_reference', 'feature_biotype', 'feature_length', 'n_cells', 'mt', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts', 'highly_variable', 'means', 'dispersions', 'dispersions_norm', 'mean', 'std'
#     uns: 'batch_condition', 'citation', 'schema_reference', 'schema_version', 'title', 'scrublet', 'log1p', 'hvg', 'author_cell_type_colors', 'pca'
#     obsm: 'X_joint_wnn_umap', 'X_umap', 'X_pca', 'Author_UMAP'
#     varm: 'PCs'

# %%
sc.pp.neighbors(adata)

# %%
# Before overriding the X_UMAP, we can as an option delete the existing one with the below command:
# del subset_adata.obsm["X_umap"]

# %%
sc.tl.umap(adata)

# %%
sc.pl.umap(adata, color = 'celltype')
# Out:
# /home/ykazci/miniconda3/envs/scenicplus/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:394: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(

# %%
sc.pl.embedding(adata, color = 'celltype', basis='Author_UMAP')
# Out:
# /home/ykazci/miniconda3/envs/scenicplus/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:394: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 44330 × 30109
#     obs: 'author_cell_type', 'age_group', 'donor_id', 'nCount_RNA', 'nFeature_RNA', 'nCount_ATAC', 'nFeature_ATAC', 'TSS_percentile', 'nucleosome_signal', 'percent_mt', 'assay_ontology_term_id', 'cell_type_ontology_term_id', 'development_stage_ontology_term_id', 'disease_ontology_term_id', 'self_reported_ethnicity_ontology_term_id', 'organism_ontology_term_id', 'sex_ontology_term_id', 'tissue_ontology_term_id', 'suspension_type', 'is_primary_data', 'batch', 'tissue_type', 'cell_type', 'assay', 'disease', 'organism', 'sex', 'tissue', 'self_reported_ethnicity', 'development_stage', 'observation_joinid', 'n_genes', 'doublet_score', 'predicted_doublet', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'celltype'
#     var: 'feature_is_filtered', 'feature_name', 'feature_reference', 'feature_biotype', 'feature_length', 'n_cells', 'mt', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts', 'highly_variable', 'means', 'dispersions', 'dispersions_norm', 'mean', 'std'
#     uns: 'batch_condition', 'citation', 'schema_reference', 'schema_version', 'title', 'scrublet', 'log1p', 'hvg', 'author_cell_type_colors', 'pca', 'neighbors', 'umap', 'celltype_colors'
#     obsm: 'X_joint_wnn_umap', 'X_umap', 'X_pca', 'Author_UMAP'
#     varm: 'PCs'
#     obsp: 'distances', 'connectivities'

# %%
adata.X.shape
# Out:
# (44330, 30109)

# %%
adata.X
# Out:
# array([[-0.06938884, -0.11069097, -0.02338199, ..., -0.02118617,
#         -0.09248725, -0.09243102],
#        [-0.06938884, -0.11069097, -0.02338199, ..., -0.02118617,
#         -0.09248725, -0.09243102],
#        [-0.06938884, -0.11069097, -0.02338199, ..., -0.02118617,
#         -0.09248725, -0.09243102],
#        ...,
#        [-0.06938884, -0.11069097, -0.02338199, ..., -0.02118617,
#         -0.09248725, -0.09243102],
#        [-0.06938884, -0.11069097, -0.02338199, ..., -0.02118617,
#         -0.09248725, -0.09243102],
#        [-0.06938884, -0.11069097, -0.02338199, ..., -0.02118617,
#         -0.09248725, -0.09243102]], dtype=float32)

# %%
if hasattr(adata, 'X'):
    print("Count matrix dimensions:", adata.X.shape)
else:
    print("Count matrix not found.")
# Out:
# Count matrix dimensions: (44330, 30109)

# %%
adata.write(os.path.join(work_dir, 'scRNA/adata_processed.h5ad'), compression='gzip')

# %%
import session_info

# %%
session_info.show()
# Out:
# <details>
# <summary>Click to view session information</summary>
# <pre>
# -----
# anndata             0.9.2
# ipykernel           6.29.2
# matplotlib          3.7.0
# numpy               1.22.0
# pandas              2.0.3
# scanpy              1.9.8
# session_info        1.0.0
# -----
# </pre>
# <details>
# <summary>Click to view modules imported as dependencies</summary>
# <pre>
# PIL                 10.2.0
# annoy               NA
# asttokens           NA
# backcall            0.2.0
# cffi                1.16.0
# cloudpickle         3.0.0
# colorama            0.4.6
# comm                0.2.1
# cycler              0.12.1
# cython_runtime      NA
# cytoolz             0.12.3
# dask                2023.5.0
# dateutil            2.8.2
# debugpy             1.8.1
# decorator           5.1.1
# defusedxml          0.7.1
# executing           2.0.1
# h5py                3.10.0
# igraph              0.11.4
# importlib_metadata  NA
# importlib_resources NA
# ipywidgets          8.1.2
# jedi                0.19.1
# jinja2              3.1.3
# joblib              1.3.2
# kiwisolver          1.4.5
# lazy_loader         NA
# leidenalg           0.10.2
# llvmlite            0.41.1
# lz4                 4.3.3
# markupsafe          2.1.5
# matplotlib_inline   0.1.6
# mpl_toolkits        NA
# natsort             8.4.0
# numba               0.58.1
# numexpr             2.8.6
# numpydoc            1.6.0
# packaging           23.2
# parso               0.8.3
# pexpect             4.9.0
# pickleshare         0.7.5
# platformdirs        4.2.0
# plotly              5.19.0
# prompt_toolkit      3.0.43
# psutil              5.9.8
# ptyprocess          0.7.0
# pure_eval           0.2.2
# pyarrow             15.0.0
# pycparser           2.21
# pydev_ipython       NA
# pydevconsole        NA
# pydevd              2.9.5
# pydevd_file_utils   NA
# pydevd_plugins      NA
# pydevd_tracing      NA
# pygments            2.17.2
# pynndescent         0.5.11
# pyparsing           3.1.1
# pytz                2024.1
# scipy               1.10.1
# scrublet            NA
# setuptools          68.2.2
# six                 1.16.0
# skimage             0.21.0
# sklearn             1.3.2
# sphinxcontrib       NA
# stack_data          0.6.3
# tblib               3.0.0
# texttable           1.7.0
# threadpoolctl       3.3.0
# tlz                 0.12.3
# toolz               0.12.1
# tornado             6.4
# tqdm                4.66.2
# traitlets           5.14.1
# typing_extensions   NA
# umap                0.5.5
# wcwidth             0.2.13
# yaml                6.0.1
# zipp                NA
# zmq                 25.1.2
# zope                NA
# </pre>
# </details> <!-- seems like this ends pre, so might as well be explicit -->
# <pre>
# -----
# IPython             8.12.3
# jupyter_client      8.6.0
# jupyter_core        5.7.1
# -----
# Python 3.8.18 (default, Sep 11 2023, 13:40:15) [GCC 11.2.0]
# Linux-3.10.0-1160.76.1.el7.x86_64-x86_64-with-glibc2.17
# -----
# Session information updated at 2024-03-17 23:41
# </pre>
# </details>
